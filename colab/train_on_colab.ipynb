# %% [markdown]
# # Deception Detection - Training on Google Colab
#
# This notebook is fully optimized for GPU training of the Multimodal Stacked Bi-LSTM model.
#
# ### 📋 Prerequisite:
# 1. **Git**: Push your current local code to a GitHub repository.
# 2. **Data**: Zip your `data/BagOfLies` and `data/processed` folders and upload them to your Google Drive (e.g., in a `BagOfLies` folder).

# %%
# 1. Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# 2. Install Fast Dependencies
# !pip install -q uv
# !uv pip install --system torch torchvision torchaudio opencv-python librosa pandas numpy scikit-learn transformers tqdm

# %%
# 3. Clone Your Repository
# Replace 'REPLACE_WITH_YOUR_REPO' with your actual username/repo name
# !git clone https://github.com/REPLACE_WITH_YOUR_REPO/BagOfLies.git /content/BagOfLies
# %cd /content/BagOfLies

# %%
# 4. Set Environment Variables for Portability
# This tells the code precisely where your code and data live on Colab/Drive
import os

os.environ['PROJECT_ROOT'] = '/content/BagOfLies'
# Update this path to where you uploaded your 'data' folder on Drive
os.environ['DATA_ROOT'] = '/content/drive/MyDrive/BagOfLies/data'

print(f"Project Root: {os.environ['PROJECT_ROOT']}")
print(f"Data Root: {os.environ['DATA_ROOT']}")

# %%
# 5. Run Training (Multi-Modal 5-Fold Cross Validation)
# The code will automatically use GPU (CUDA) and Mixed Precision (AMP)
# %env PYTHONPATH=/content/BagOfLies
# !python src/train.py
